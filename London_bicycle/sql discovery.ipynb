# %%
SELECT
   end_station_id,
   end_station_name,
   COUNT(rental_id)
FROM
  `bigquery-public-data.london_bicycles.cycle_hire`
GROUP BY end_station_id,
  end_station_name
ORDER BY
  end_station_name ASC;
